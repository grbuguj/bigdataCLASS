# %% [markdown]
# <a href="https://colab.research.google.com/github/grbuguj/bigdataCLASS/blob/main/5weeks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from re import T
import pandas as pd

titanic='https://github.com/sehakflower/data/blob/main/titanic.xlsx?raw=true'
titanic_df=pd.read_excel(titanic, sheet_name='titanic3')
#titanic_df.pivot_table(index='pclass', columns='sex', values='survived') 등급/성별에 대한 생존여부 확인
#titanic_df.groupby('survived').count() #생존에 따른 나누기
#titanic_df.groupby('survived').mean() #열이 있을때 평균 하면 오류!
#titanic_df.groupby('sex').sum(numeric_only=True) #숫자만 취급 출력
#titanic_df.groupby('sex')['survived'].mean() #성별에 따른 생존률 평균
#titanic_df.groupby(['sex', 'survived']).mean(numeric_only=True) #성별과 생존에 따른. 모든거의 평균
df = titanic_df.groupby(['sex', 'survived']).mean(numeric_only=True)

#df.unstack('sex') #행 열 바꾸기
#df.unstack('survived') # 행열 바꾸기 성별에 따른
#survived = df.unstack("survived")
#survived['age'] # 셩별과 생존에 따른 age의 평균
#survived_stack = survived.stack('survived')
#survived_stack[0:3]
df1=df.reset_index()
df1
# Out:
#       sex  survived    pclass        age     sibsp     parch       fare  \
# 0  female         0  2.826772  25.255208  1.031496  0.889764  22.324084
# 1  female         1  1.902655  29.815354  0.510324  0.536873  55.142048
# 2    male         0  2.439883  31.516412  0.426686  0.224340  23.545868
# 3    male         1  2.086957  26.977778  0.360248  0.347826  37.189053
#
#         body
# 0  166.62500
# 1        NaN
# 2  160.39823
# 3        NaN
